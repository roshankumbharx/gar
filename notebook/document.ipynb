# %% [markdown]
# Data Ingestion

# %%
from langchain_core.documents import Document

# %%
import os

os.makedirs('../data/text_files',exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader('../data/text_files/python_intro.txt',encoding='utf-8')

document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader('../data/text_files',loader_cls=TextLoader,loader_kwargs={'encoding':'utf-8'},show_progress=False,glob='**/*.txt')
document = dir_loader.load()
print(document)
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '), Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
# for pdf files

from langchain_community.document_loaders import DirectoryLoader,PyPDFLoader,PyMuPDFLoader

dir_loader = DirectoryLoader('../data/pdfs/',loader_cls=PyMuPDFLoader,glob='**/*.pdf',show_progress=False)

pdf_document = dir_loader.load()
pdf_document
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-10-17T13:40:03+05:30', 'source': '..\\data\\pdfs\\MyToken_Blockchain_Report.pdf', 'file_path': '..\\data\\pdfs\\MyToken_Blockchain_Report.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'python-docx', 'subject': '', 'keywords': '', 'moddate': '2025-10-17T13:40:03+05:30', 'trapped': '', 'modDate': "D:20251017134003+05'30'", 'creationDate': "D:20251017134003+05'30'", 'page': 0}, page_content='Exp 8 \n \nAIM \nCreating and deploying an ERC-20 token MyToken using Solidity smart \ncontracts and modern tooling (Hardhat 3 Beta, TypeScript). Build, \ndeploy and interact with the token contract, demonstrating the \ncomplete blockchain workflow (development , deployment , interaction \n, testing). \nTHEORY \n1. Blockchain Fundamentals \nBlockchain provides a decentralized, immutable ledger \nwhere transactions (token minting, transfers) are \nrecorded transparently and tamper-resistantly. \nTokenization using standards like ERC-20 enables \ninteroperable digital assets across wallets and dApps. \n2. ERC-20 Standard & OpenZeppelin \nERC-20 is a widely adopted token interface on \nEthereum that defines functions such as totalSupply(), \nbalanceOf(), transfer(), approve(), and transferFrom(). \nOpenZeppelin provides battle-tested implementations \nto reduce vulnerability risk; MyToken inherits from \nOpenZeppelin’s ERC-20 base.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-10-17T13:40:03+05:30', 'source': '..\\data\\pdfs\\MyToken_Blockchain_Report.pdf', 'file_path': '..\\data\\pdfs\\MyToken_Blockchain_Report.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'python-docx', 'subject': '', 'keywords': '', 'moddate': '2025-10-17T13:40:03+05:30', 'trapped': '', 'modDate': "D:20251017134003+05'30'", 'creationDate': "D:20251017134003+05'30'", 'page': 1}, page_content='3. Development Tooling (Hardhat, TypeScript, viem, \nethers) \nHardhat 3 Beta (Ignition) is used for compiling and \ndeploying contracts; TypeScript improves safety for \ndeployment and interaction scripts. Libraries like viem \nand ethers are used for scripting interactions, sending \ntransactions, and writing tests. This combination gives \nmodern, testable workflows for smart contract \ndevelopment. \n4. Token Lifecycle & Workflows \nTypical lifecycle steps: contract design → compile → \ndeploy to a network (local/testnet) → interact via \nscripts or frontend → test automated behaviors \n(transfers, allowances, events). Logs and events form an \nimmutable audit trail. \nALGORITHM / IMPLEMENTATION STEPS \n1. Step 1 — Environment setup: Install Node.js, \nnpm/yarn, initialize project, install dependencies, \nconfigure Hardhat. \n2. Step 2 — Smart contract (Solidity): Create \nMyToken.sol, inherit from ERC20, set name/symbol, \nmint initial supply.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-10-17T13:40:03+05:30', 'source': '..\\data\\pdfs\\MyToken_Blockchain_Report.pdf', 'file_path': '..\\data\\pdfs\\MyToken_Blockchain_Report.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'python-docx', 'subject': '', 'keywords': '', 'moddate': '2025-10-17T13:40:03+05:30', 'trapped': '', 'modDate': "D:20251017134003+05'30'", 'creationDate': "D:20251017134003+05'30'", 'page': 2}, page_content='3. Step 3 — Compile & Configure: Compile using \nHardhat and verify compiler/network setup. \n4. Step 4 — Deployment: Deploy contract using Hardhat \nIgnition with initial supply parameters. \n5. Step 5 — Interaction scripts: Write scripts to call \ntotalSupply, balanceOf, transfer, and approve \nfunctions. \n6. Step 6 — Testing: Create automated tests for transfer, \nbalance updates, and allowances. \n7. Step 7 — Optional Frontend / Wallet Integration: \nCreate UI to interact with contract through \nMetaMask. \n8. Step 8 — Verification & Documentation: Verify \ncontract and include deployed address and \nscreenshots. \nFLOWCHART \nFlowchart showing: Write Contract → Compile → \nDeploy → Interact/Test → Observe Output/Events. \nRESULTS / OUTPUT'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-10-17T13:40:03+05:30', 'source': '..\\data\\pdfs\\MyToken_Blockchain_Report.pdf', 'file_path': '..\\data\\pdfs\\MyToken_Blockchain_Report.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'python-docx', 'subject': '', 'keywords': '', 'moddate': '2025-10-17T13:40:03+05:30', 'trapped': '', 'modDate': "D:20251017134003+05'30'", 'creationDate': "D:20251017134003+05'30'", 'page': 3}, page_content='• Token Creation — compilation output and contract \nbytecode/ABI generation. \n• Token Deployment — deployer address, deployed \ncontract address, initial supply assigned.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-10-17T13:40:03+05:30', 'source': '..\\data\\pdfs\\MyToken_Blockchain_Report.pdf', 'file_path': '..\\data\\pdfs\\MyToken_Blockchain_Report.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'python-docx', 'subject': '', 'keywords': '', 'moddate': '2025-10-17T13:40:03+05:30', 'trapped': '', 'modDate': "D:20251017134003+05'30'", 'creationDate': "D:20251017134003+05'30'", 'page': 4}, page_content='• Sample Interactions — balanceOf, transfer \ntransaction, Transfer event logs. \nOBSERVATIONS \n• Using OpenZeppelin reduces security risk and speeds \nup development. \n• Hardhat Ignition simplifies repeatable deployments \nand produces deployment artifacts for auditing. \n• Automated tests catch common mistakes before \ndeployment. \nCONCLUSION \nThe MyToken project demonstrates the end-to-end \nlifecycle of an ERC-20 token: writing secure smart \ncontracts using OpenZeppelin, compiling and deploying \nwith Hardhat 3 Beta, interacting via viem/ethers, and \nvalidating behavior through automated tests. This \napproach reflects real-world dApp workflows \nemphasizing modular, testable, and auditable \ndevelopment.'),
#  Document(metadata={'producer': '', 'creator': 'WPS Writer', 'creationdate': '2025-10-15T00:44:18+05:30', 'source': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'file_path': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'total_pages': 11, 'format': 'PDF 1.7', 'title': 'BDA mini Project shweta', 'author': 'vedika chavan', 'subject': '', 'keywords': '', 'moddate': '2025-10-15T00:44:18+05:30', 'trapped': '', 'modDate': "D:20251015004418+05'30'", 'creationDate': "D:20251015004418+05'30'", 'page': 0}, page_content='1\nMental Health Assistant Chatbot\nSubmitted in partial fulfillment of the requirements of the degree\nBACHELOROF ENGINEERING\nIN\nCOMPUTER ENGINEERING (AI&ML)\nSem – VII\nBy\nDeepanshu Singh [B36]\nPraful Prasad [B27]\nSupervisor\nProf. Varsha Mashoria\nDepartment of Computer Engineering (AI&ML)\nLokmanya Tilak College of Engineering\nKopar Khairne, Navi Mumbai - 400 709\nUniversity of Mumbai\n(AY 2025-26)'),
#  Document(metadata={'producer': '', 'creator': 'WPS Writer', 'creationdate': '2025-10-15T00:44:18+05:30', 'source': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'file_path': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'total_pages': 11, 'format': 'PDF 1.7', 'title': 'BDA mini Project shweta', 'author': 'vedika chavan', 'subject': '', 'keywords': '', 'moddate': '2025-10-15T00:44:18+05:30', 'trapped': '', 'modDate': "D:20251015004418+05'30'", 'creationDate': "D:20251015004418+05'30'", 'page': 1}, page_content='2\nCONTENTS\nChapter\nNo.\nChapter Name\nPage No.\n1.\nAbstract\n03\n2.\nIntroduction\n04\n3.\nPurpose /\nObjective\n04\n4.\nProposed System\n05\n5.\nImplementation\n06\n6.\nResult / Output\n07 to 09\n7.\nConclusion\n10\n8.\nReferences\n10'),
#  Document(metadata={'producer': '', 'creator': 'WPS Writer', 'creationdate': '2025-10-15T00:44:18+05:30', 'source': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'file_path': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'total_pages': 11, 'format': 'PDF 1.7', 'title': 'BDA mini Project shweta', 'author': 'vedika chavan', 'subject': '', 'keywords': '', 'moddate': '2025-10-15T00:44:18+05:30', 'trapped': '', 'modDate': "D:20251015004418+05'30'", 'creationDate': "D:20251015004418+05'30'", 'page': 2}, page_content='3\n1. ABSTRACT\nIn the contemporary digital era, mental health has emerged as one of the most significant global challenges,\naffecting individuals across all age groups, professions, and social backgrounds. The rising levels of stress,\nanxiety, and emotional exhaustion, fueled by fast-paced lifestyles, excessive screen exposure, and reduced\nhuman interaction, have created a pressing need for accessible psychological support systems.\nUnfortunately, despite growing awareness, professional mental health services are still limited due to high\ncosts, geographical inaccessibility, and the social stigma associated with seeking therapy. This situation\nhighlights the demand for intelligent, technology-driven systems capable of offering reliable and\nempathetic emotional assistance.\nTo address these challenges, MediMind, an NLP-Based Mental Health Assistant Chatbot, has been\ndeveloped. MediMind leverages advanced Natural Language Processing (NLP) and Retrieval-\nAugmented Generation (RAG) architectures to create an AI-driven conversational agent capable of\ninteracting with users in a natural, empathetic, and context-aware manner. The chatbot is designed to assist\nusers experiencing stress, anxiety, or emotional distress by providing supportive and informative responses\nbased on verified psychological resources. It uses LangChain for managing retrieval and response flow,\nFAISS (Facebook AI Similarity Search) for efficient vector-based document storage and retrieval, and\nHugging Face embeddings to convert textual data into meaningful numerical representations. The Groq\nAPI ensures efficient model inference, producing quick and coherent responses to user queries.\nThe application’s user interface is implemented using Streamlit, which offers a lightweight and interactive\nplatform for real-time chatbot interaction. The system combines the strengths of retrieval-based and\ngenerative NLP approaches, ensuring both factual correctness and emotional sensitivity. When a user\ninputs a query, the system searches its embedded document base for relevant content, retrieves the closest\nmatches, and uses a large language model to construct a personalized, natural response. This hybrid\napproach ensures that MediMind is not merely reactive but also contextually intelligent.\nBy combining AI technology with psychological insight, MediMind demonstrates the potential of NLP in\naddressing real-world emotional and social problems. It provides users with immediate, stigma-free access\nto a supportive conversational agent that encourages mental wellness. While not a replacement for\nprofessional therapy, it acts as a valuable first line of digital support, promoting early intervention,\nawareness, and self-care. MediMind exemplifies how AI, when used responsibly, can empower individuals\nto seek comfort, clarity, and understanding through empathetic human-computer interaction.'),
#  Document(metadata={'producer': '', 'creator': 'WPS Writer', 'creationdate': '2025-10-15T00:44:18+05:30', 'source': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'file_path': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'total_pages': 11, 'format': 'PDF 1.7', 'title': 'BDA mini Project shweta', 'author': 'vedika chavan', 'subject': '', 'keywords': '', 'moddate': '2025-10-15T00:44:18+05:30', 'trapped': '', 'modDate': "D:20251015004418+05'30'", 'creationDate': "D:20251015004418+05'30'", 'page': 3}, page_content='4\n2. INTRODUCTION\nThe increasing prevalence of mental health disorders in modern society has made psychological well-being\none of the most critical areas of focus in public health and technology. Stress, anxiety, and depression have\nbecome widespread due to factors such as social isolation, intense competition, academic pressure, and the\ninfluence of digital environments. Despite the growing recognition of these issues, millions of people\nworldwide still struggle to access timely and affordable mental health care. The stigma associated with\ndiscussing mental health problems often prevents individuals from seeking help, creating a widening gap\nbetween the need for support and the availability of professional care.\nArtificial Intelligence (AI) and Natural Language Processing (NLP) have emerged as promising\ntechnologies that can help bridge this gap. AI-driven conversational agents have the potential to simulate\nhuman-like dialogue and provide users with emotional support, education, and guidance. By using large\nlanguage models and retrieval-based techniques, these systems can understand natural human language and\nrespond appropriately to user inputs. Such chatbots are not designed to replace psychologists but to act as\ndigital companions that promote self-awareness, emotional resilience, and mental health literacy.\nMediMind, an NLP-Based Mental Health Assistant Chatbot, is one such initiative aimed at providing\naccessible and empathetic digital mental wellness assistance. The chatbot leverages LangChain to manage\ndialogue flow and data retrieval pipelines, FAISS vector databases to store and search embedded text\nrepresentations, and Hugging Face embeddings to process semantic meanings effectively. When a user\nasks a question or expresses an emotion, MediMind retrieves relevant information from its database and\ngenerates a human-like, compassionate response using a Retrieval-Augmented Generation (RAG)\nframework. This ensures that the answers are both informative and contextually relevant to the user’s\nemotional state.\nThe front-end interface of MediMind is implemented using Streamlit, offering users a simple, interactive,\nand friendly environment for communication. The integration with the Groq API enhances system\nperformance, reducing latency and enabling near-instantaneous responses. The chatbot is capable of\nhandling queries related to stress management, relaxation techniques, emotional awareness, and general\npsychological well-being.\nUltimately, MediMind represents the integration of AI and psychology for social good. It creates a non-\njudgmental digital space where users can express their thoughts freely and receive supportive responses.\nThrough its interactive design, contextual understanding, and emotional sensitivity, MediMind highlights\nhow responsible AI implementation can make mental wellness resources more inclusive, accessible, and\ncompassionate in the modern digital world.'),
#  Document(metadata={'producer': '', 'creator': 'WPS Writer', 'creationdate': '2025-10-15T00:44:18+05:30', 'source': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'file_path': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'total_pages': 11, 'format': 'PDF 1.7', 'title': 'BDA mini Project shweta', 'author': 'vedika chavan', 'subject': '', 'keywords': '', 'moddate': '2025-10-15T00:44:18+05:30', 'trapped': '', 'modDate': "D:20251015004418+05'30'", 'creationDate': "D:20251015004418+05'30'", 'page': 4}, page_content='5\n3. PURPOSE / OBJECTIVE\nThe main purpose of the MediMind project is to create an intelligent chatbot that uses Artificial\nIntelligence and Natural Language Processing to engage users in meaningful conversations about mental\nhealth. It aims to provide empathetic, informative, and contextually relevant responses that can help users\nmanage emotional stress, gain awareness about mental well-being, and encourage healthy coping\nmechanisms.\nIn today’s world, where mental health concerns are rising rapidly, it is essential to leverage technology to\nreach people who may not otherwise seek professional help due to fear, stigma, or lack of resources.\nMediMind serves as a bridge, offering accessible support through an easy-to-use web-based platform. It not\nonly responds to user queries but also helps promote emotional literacy and self-reflection.\nThe objectives of MediMind are outlined as follows:\nTo design and develop an AI-powered chatbot capable of understanding and processing natural language\nrelated to mental wellness topics.\n\uf0d8\nTo implement Retrieval-Augmented Generation (RAG) using LangChain to ensure contextually\naccurate and relevant responses.\n\uf0d8\nTo utilize FAISS vector databases for efficient semantic retrieval of information from preprocessed\nmental health documents.\n\uf0d8\nTo apply Hugging Face embeddings to represent sentences as numerical vectors, allowing the system\nto perform high-accuracy similarity matching.\n\uf0d8\nTo integrate Groq API for efficient inference, ensuring low-latency and reliable real-time response\ngeneration.\n\uf0d8\nTo develop a clean, interactive, and user-friendly web interface using Streamlit, allowing seamless\nhuman-computer interaction.\n\uf0d8\nTo promote mental health awareness and encourage open communication about emotional well-being\nthrough accessible technology.\n\uf0d8\nTo maintain user privacy and confidentiality, ensuring that users can engage in conversations without\njudgment or exposure.\n\uf0d8\nTo demonstrate how AI can be responsibly applied to social and emotional domains to support human\nwell-being.\nBy achieving these objectives, MediMind aspires to demonstrate how cutting-edge AI techniques can be\nintegrated into socially impactful projects. It provides an example of how machine learning, language\nmodeling, and vector-based retrieval systems can be utilized to create tools that not only inform but also\nempathize — contributing to a more mentally aware and emotionally intelligent digital society.'),
#  Document(metadata={'producer': '', 'creator': 'WPS Writer', 'creationdate': '2025-10-15T00:44:18+05:30', 'source': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'file_path': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'total_pages': 11, 'format': 'PDF 1.7', 'title': 'BDA mini Project shweta', 'author': 'vedika chavan', 'subject': '', 'keywords': '', 'moddate': '2025-10-15T00:44:18+05:30', 'trapped': '', 'modDate': "D:20251015004418+05'30'", 'creationDate': "D:20251015004418+05'30'", 'page': 5}, page_content='6\n4. PROPOSED SYSTEM\nThe proposed system, MediMind: NLP-Based Mental Health Assistant Chatbot, is designed to create a\ndigital platform that enables intelligent and empathetic conversations centered on mental wellness. The\nchatbot functions by combining retrieval-based search with generative AI response generation,\nimplemented through the Retrieval-Augmented Generation (RAG) framework. This hybrid approach\nensures that the chatbot’s responses are not only contextually accurate but also emotionally aligned with the\nuser’s query.\nThe architecture of MediMind consists of three primary layers: Knowledge Base Layer, Processing Layer,\nand User Interface Layer.\n1.Knowledge Base Layer:\nThis layer forms the foundation of the chatbot’s intelligence. It contains a collection of mental\nhealth resources and documents that have been preprocessed and embedded using Hugging Face\nsentence transformers. These embeddings are stored in a FAISS vector database, enabling\nefficient similarity searches based on semantic meaning rather than mere keyword matching. This\nallows the system to understand the intent behind user queries more accurately.\n2.Processing Layer:\nThe processing layer performs the core computational tasks. It uses LangChain to orchestrate the\npipeline — taking user input, converting it into an embedding, performing a similarity search in the\nFAISS database, retrieving the top relevant documents, and forwarding them along with the query\nto the Groq API-powered large language model. The LLM then generates a natural, empathetic\nresponse that reflects both the retrieved content and the user’s emotional tone. This ensures that\nMediMind maintains a balance between factual accuracy and emotional sensitivity.\n3.User Interface Layer:\nThe front-end is developed using Streamlit, providing a web-based conversational environment that\nis both visually minimalistic and interactive. Users can chat in real time, ask questions, and receive\nimmediate, meaningful responses. The interface is intentionally designed to be calming and simple,\nreflecting the system’s goal of promoting mental wellness.\nIn operation, when a user sends a message, the chatbot first processes it semantically to understand intent. It\nthen retrieves relevant knowledge from the FAISS database and uses generative AI to compose a response\nthat is coherent, contextually appropriate, and emotionally supportive. This design ensures that MediMind’s\nreplies go beyond surface-level responses, providing genuine understanding and guidance.\nOverall, the proposed system demonstrates how AI technologies like NLP, embeddings, and retrieval\nmodels can be effectively integrated to create digital platforms that care for human emotions. MediMind\nnot only offers real-time psychological guidance but also represents the ethical and compassionate side of\nAI — making technology a tool for healing and awareness rather than just automation.'),
#  Document(metadata={'producer': '', 'creator': 'WPS Writer', 'creationdate': '2025-10-15T00:44:18+05:30', 'source': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'file_path': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'total_pages': 11, 'format': 'PDF 1.7', 'title': 'BDA mini Project shweta', 'author': 'vedika chavan', 'subject': '', 'keywords': '', 'moddate': '2025-10-15T00:44:18+05:30', 'trapped': '', 'modDate': "D:20251015004418+05'30'", 'creationDate': "D:20251015004418+05'30'", 'page': 6}, page_content='7\n5.Implementation:'),
#  Document(metadata={'producer': '', 'creator': 'WPS Writer', 'creationdate': '2025-10-15T00:44:18+05:30', 'source': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'file_path': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'total_pages': 11, 'format': 'PDF 1.7', 'title': 'BDA mini Project shweta', 'author': 'vedika chavan', 'subject': '', 'keywords': '', 'moddate': '2025-10-15T00:44:18+05:30', 'trapped': '', 'modDate': "D:20251015004418+05'30'", 'creationDate': "D:20251015004418+05'30'", 'page': 7}, page_content='8\n6.Results'),
#  Document(metadata={'producer': '', 'creator': 'WPS Writer', 'creationdate': '2025-10-15T00:44:18+05:30', 'source': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'file_path': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'total_pages': 11, 'format': 'PDF 1.7', 'title': 'BDA mini Project shweta', 'author': 'vedika chavan', 'subject': '', 'keywords': '', 'moddate': '2025-10-15T00:44:18+05:30', 'trapped': '', 'modDate': "D:20251015004418+05'30'", 'creationDate': "D:20251015004418+05'30'", 'page': 8}, page_content='9'),
#  Document(metadata={'producer': '', 'creator': 'WPS Writer', 'creationdate': '2025-10-15T00:44:18+05:30', 'source': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'file_path': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'total_pages': 11, 'format': 'PDF 1.7', 'title': 'BDA mini Project shweta', 'author': 'vedika chavan', 'subject': '', 'keywords': '', 'moddate': '2025-10-15T00:44:18+05:30', 'trapped': '', 'modDate': "D:20251015004418+05'30'", 'creationDate': "D:20251015004418+05'30'", 'page': 9}, page_content='10\n7. Conclusion\nThe MediMind: NLP-Based Mental Health Assistant Chatbot effectively demonstrates how artificial\nintelligence and natural language processing can be applied to support mental wellness. By using\nLangChain, FAISS, and Hugging Face embeddings, the system retrieves relevant information and\ngenerates accurate, empathetic responses through a Retrieval-Augmented Generation (RAG) approach.\nThe chatbot, deployed on a Streamlit interface, provides a simple and accessible platform for users to\ndiscuss emotional concerns and receive supportive feedback. Although it does not replace professional\ntherapy, MediMind serves as an early support tool that encourages awareness, reflection, and mental well-\nbeing. Overall, the project highlights the role of AI in creating intelligent, compassionate, and accessible\ndigital solutions for mental health care.\n8. References\nR. J. Williams, “AI-Powered Chatbots for Mental Health Support,” Journal of Artificial Intelligence\nResearch, 2024.\nS. Gupta and N. Sharma, “Retrieval-Augmented Generation for Conversational AI,” IEEE Transactions on\nComputational Intelligence, 2025.\nP. Johnson and L. Smith, “Utilizing FAISS for Efficient Semantic Search,” ACM Digital Library, 2024.\nM. T. Nguyen, “Natural Language Processing in Psychological Applications,” Elsevier Expert Systems with\nApplications, 2025.\nA. Brown, “Integrating LangChain and Groq API for Real-Time NLP Systems,” International Journal of\nAI & Data Science, 2025.'),
#  Document(metadata={'producer': '', 'creator': 'WPS Writer', 'creationdate': '2025-10-15T00:44:18+05:30', 'source': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'file_path': '..\\data\\pdfs\\nlp report_praful 1.pdf', 'total_pages': 11, 'format': 'PDF 1.7', 'title': 'BDA mini Project shweta', 'author': 'vedika chavan', 'subject': '', 'keywords': '', 'moddate': '2025-10-15T00:44:18+05:30', 'trapped': '', 'modDate': "D:20251015004418+05'30'", 'creationDate': "D:20251015004418+05'30'", 'page': 10}, page_content='11'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-10-25T21:44:00+05:30', 'source': '..\\data\\pdfs\\Tester Automation review paper final.pdf', 'file_path': '..\\data\\pdfs\\Tester Automation review paper final.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': 'Pramod Jaiswar', 'subject': '', 'keywords': '', 'moddate': '2025-10-25T21:44:00+05:30', 'trapped': '', 'modDate': "D:20251025214400+05'30'", 'creationDate': "D:20251025214400+05'30'", 'page': 0}, page_content='e-ISSN: 2582-5208 \nInternational Research Journal of Modernization in Engineering Technology and Science \n( Peer-Reviewed, Open Access, Fully Refereed International Journal ) \nVolume:07/Issue:08/August-2025       Impact Factor- 8.187                              www.irjmets.com   \nwww.irjmets.com                              @International Research Journal of Modernization in Engineering, Technology and Science \n [1] \nAI-Powered Autonomous Software Testing System Using LLMs, RAG, and \nMulti-Agent Orchestration,  \nSmita Ganjare*1,Aadi Kumbhar*2,Roshan Kumbhar*3,Nikhil Jaiswar*4 ,Harsh Keella*5 \n*1Assistant Professor, Department of Computer Science and Engineering (Artificial Intelligence and \nMachine Learning), Lokmanya Tilak College of Engineering, Navi Mumbai, Maharashtra, India \n*2,3,4,5 Student, Department of Computer Science and Engineering (Artificial Intelligence and \nMachine Learning), Lokmanya Tilak College of Engineering, Navi Mumbai, Maharashtra, India  \n \nABSTRACT \nThe increasing complexity of software systems and the \ndemand for faster release cycles have highlighted the \nlimitations of traditional testing methods that rely \nheavily on human intervention. Manual and semi-\nautomated testing approaches struggle to maintain \nquality assurance within agile and DevOps pipelines, \nwhere codebases evolve rapidly. To overcome these \nchallenges, Artificial Intelligence (AI) has emerged as \na powerful enabler for automating and optimizing the \nsoftware testing lifecycle. In particular, Retrieval-\nAugmented Generation (RAG) and Multi-Agent \nSystems (MAS) have gained significant attention for \ntheir potential to create context-aware, adaptive, and \ncollaborative testing frameworks. This literature survey \nprovides a comprehensive overview of existing \nresearch, models, and frameworks that integrate AI-\ndriven automation into software testing through RAG \nand multi-agent architectures. The study explores how \nRAG enables dynamic knowledge retrieval from \nproject \ndocumentation, \nrequirements, \nand \ncode \nrepositories to enhance test case generation, while \nmulti-agent \nsystems \nfacilitate \ndistributed \ntest \nexecution, \nbug \nclassification, \nand \nintelligent \ncoordination among agents. Various studies are \nreviewed to identify key advancements, comparative \nmethodologies, and gaps in the current research \nlandscape. The findings highlight that the fusion of \nRAG and MAS can significantly improve test coverage, \nefficiency, and fault detection accuracy, paving the way \nfor fully autonomous, self-learning testing ecosystems \nin continuous integration (CI/CD) environments \nI. \n INTRODUCTION \nSoftware testing is a critical phase in the software \ndevelopment lifecycle, ensuring that applications are \nreliable, functional, and meet quality standards. With \nthe increasing complexity of modern software systems \nand the rapid pace of development in Agile and DevOps \nenvironments, \ntraditional \ntesting \nmethods—both \nmanual \nand \nsemi-automated—are \nbecoming \nincreasingly inadequate. Manual testing is labor-\nintensive, error-prone, and difficult to scale, while \nconventional automated testing frameworks require \nfrequent script updates and significant human \noversight. These limitations create delays in release \ncycles, reduce test coverage, and make it challenging to \nmaintain software qualit ...
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-10-25T21:44:00+05:30', 'source': '..\\data\\pdfs\\Tester Automation review paper final.pdf', 'file_path': '..\\data\\pdfs\\Tester Automation review paper final.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': 'Pramod Jaiswar', 'subject': '', 'keywords': '', 'moddate': '2025-10-25T21:44:00+05:30', 'trapped': '', 'modDate': "D:20251025214400+05'30'", 'creationDate': "D:20251025214400+05'30'", 'page': 1}, page_content='e-ISSN: 2582-5208 \nInternational Research Journal of Modernization in Engineering Technology and Science \n( Peer-Reviewed, Open Access, Fully Refereed International Journal ) \nVolume:07/Issue:08/August-2025       Impact Factor- 8.187                              www.irjmets.com   \nwww.irjmets.com                              @International Research Journal of Modernization in Engineering, Technology and Science \n [2] \nand future directions toward fully autonomous, \nintelligent testing ecosystems. \nII. \nLITERATURE REVIEW  \n1) Search-Based \nSoftware \nTesting: \nPast, \nPresent and Future (M. Harman et al., \n2019) \nThis paper explores search-based software \ntesting \ntechniques \nthat \nuse \nAI \nand \noptimization algorithms to generate test cases. \nIt highlights how machine learning improves \ntest coverage and identifies defects early. \nHowever, the scalability of these approaches \nin large codebases remains limited. \n2) NLP-Based Requirement Analysis for \nAutomated Test Case Generation (K. \nLakhotia \net \nal., \n2020) \nThe study demonstrates the use of natural \nlanguage processing to extract test cases \ndirectly from requirement documents. The \napproach improves automation in test case \ncreation but struggles to adapt dynamically to \nfrequent code changes in agile environments. \n3) Reinforcement Learning for Regression \nTest Optimization (S. Chen et al., 2021) \nThis \nresearch \nintroduces \nreinforcement \nlearning agents for regression test selection, \nenhancing the prioritization of tests based on \nhistorical results. It significantly improves \nregression efficiency but requires large \ndatasets for training. \n4) Large \nLanguage \nModels \nfor \nCode \nUnderstanding \n(OpenAI, \n2023) \nOpenAI’s work focuses on GPT-based models \nto comprehend code and generate structured \ntest scripts. These models assist in automated \ntest generation but lack direct execution \norchestration \nfor \nreal-time \ntesting \nenvironments. \n5) Multi-Agent AI for Intelligent Automation \n(Google \nDeepMind, \n2024) \nThe \npaper presents \na multi-agent \nAI \nframework where cooperative agents divide \ntasks for automated testing. It demonstrates \neffective parallel test execution but introduces \nchallenges in coordination and system \ncomplexity. \n6) Transfer \nLearning \nTechniques \nfor \nSoftware Defect Prediction (P. N. Ramesh \net \nal., \n2022) \nThis study applies transfer learning to improve \ndefect prediction accuracy in software \nsystems. The model can generalize across \nprojects but involves high computational costs \nand training requirements. \n7) Hybrid AI-Based Model for Test Case \nPrioritization (L. Xu and T. Zhang, 2023) \nThe research combines multiple AI techniques \nto prioritize test cases for regression testing. It \nenhances \ntesting \nefficiency \nbut \nfaces \nchallenges in scalability for large-scale \nenterprise applications. \n8) Knowledge Graph-Driven Code Testing for \nDependency Management (T. Singh and A. \nPatel, \n2023) \nThis approach leverages knowledge graphs to \nunderstand code dependencies and generate \ncontext-aware test cases. While it improves \ntesting accuracy, maintaining the knowledge \ngraph is resource-intensive. \n9) Self-Healing Automation Framework for \nSoftware Testing (IBM Research, 2024) \nIBM’s framework introduces self-healing \ntests that detect and fix flaky or broken ...
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-10-25T21:44:00+05:30', 'source': '..\\data\\pdfs\\Tester Automation review paper final.pdf', 'file_path': '..\\data\\pdfs\\Tester Automation review paper final.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': 'Pramod Jaiswar', 'subject': '', 'keywords': '', 'moddate': '2025-10-25T21:44:00+05:30', 'trapped': '', 'modDate': "D:20251025214400+05'30'", 'creationDate': "D:20251025214400+05'30'", 'page': 2}, page_content='e-ISSN: 2582-5208 \nInternational Research Journal of Modernization in Engineering Technology and Science \n( Peer-Reviewed, Open Access, Fully Refereed International Journal ) \nVolume:07/Issue:08/August-2025       Impact Factor- 8.187                              www.irjmets.com   \nwww.irjmets.com                              @International Research Journal of Modernization in Engineering, Technology and Science \n [3] \nThis study uses NLP models to convert \nrequirements directly into executable test \ncases. It improves automation but lacks \nintegration with distributed test execution \nframeworks. \n14) Using GPT Models for Automated Code \nReview and Testing (C. Tan and P. Singh, \n2023)  \nThe paper applies GPT-based models to \ngenerate test scripts and assist in code review. \nIt enhances productivity but does not directly \nhandle multi-environment test execution. \n15) Intelligent Bug Triaging using Deep \nLearning (H. Das and N. Kapoor, 2023)  \nThis research leverages deep learning for \nautomatic bug triaging, grouping similar \ndefects \nand \npredicting \nseverity. \nWhile \naccurate, the system needs continuous \nretraining to remain effective. \n16) AI-Augmented \nSoftware \nQuality \nAssurance (Microsoft Research, 2024)  \nMicrosoft’s work integrates AI to assist QA \nprocesses, including test case generation, \nexecution, and bug analysis. It improves \noverall \ntesting \nefficiency \nbut \nrequires \nintegration with existing CI/CD pipelines. \n17) AI-Driven Continuous Testing in Agile \nEnvironments (J. Verma et al., 2023)  \nThis study explores AI-powered continuous \ntesting frameworks for Agile projects. It \nreduces \ntesting \ndelays \nand \nincreases \nadaptability but faces challenges in multi-\nagent coordination.\n \n18) Automation of Test Case Execution using \nMulti-Agent Reinforcement Learning (H. \nChoudhary \nand \nM. \nSinha, \n2024)  \nThe paper presents multi-agent reinforcement \nlearning for distributed test execution. It \noptimizes task allocation and execution \nefficiency but adds complexity in agent \ncommunication. \n19) Retrieval-Augmented \nGeneration \nfor \nSoftware Development Tasks (Y. Chen and \nR. \nKumar, \n2024)  \nThis research demonstrates RAG applications \nin software tasks, including test case \ngeneration and bug reporting. It improves \ncontext-aware \nautomation \nbut \nrequires \nextensive document and code repositories. \n20) Machine \nLearning \nAlgorithm \nfor \nEnhanced SVM Technique to Predict \nStress (T. Mohana Priya et al., 2020)  \nAlthough this paper primarily focuses on \npredictive \nanalytics \nusing \nSVM, \nits \nmethodology for intelligent classification and \npattern recognition is relevant for designing \nautomated bug detection systems in software \ntesting.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-10-25T21:44:00+05:30', 'source': '..\\data\\pdfs\\Tester Automation review paper final.pdf', 'file_path': '..\\data\\pdfs\\Tester Automation review paper final.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': 'Pramod Jaiswar', 'subject': '', 'keywords': '', 'moddate': '2025-10-25T21:44:00+05:30', 'trapped': '', 'modDate': "D:20251025214400+05'30'", 'creationDate': "D:20251025214400+05'30'", 'page': 3}, page_content='e-ISSN: 2582-5208 \nInternational Research Journal of Modernization in Engineering Technology and Science \n( Peer-Reviewed, Open Access, Fully Refereed International Journal ) \nVolume:07/Issue:08/August-2025       Impact Factor- 8.187                              www.irjmets.com   \nwww.irjmets.com                              @International Research Journal of Modernization in Engineering, Technology and Science \n [2] \nSr \nNo \nTitle \nAuthor(s) \nYear \nPaper Summary \nResearch Gap \n1 \nSearch-Based Software \nTesting: Past, Present and \nFuture \nM. Harman \net al. \n2019 \nExplores AI-based test \ngeneration using search and \noptimization algorithms to \nimprove test coverage. \nLimited scalability for large \nprojects. \n2 \nNLP-Based Requirement \nAnalysis for Automated \nTest Case Generation \nK. Lakhotia \net al. \n2020 Uses NLP to extract test cases \nfrom requirement documents. \nStruggles with dynamic \ncode changes. \n3 \nReinforcement Learning \nfor Regression Test \nOptimization \nS. Chen et \nal. \n2021 \nRL agents prioritize \nregression tests using \nhistorical results. \nRequires large datasets. \n4 Large Language Models \nfor Code Understanding \nOpenAI \n2023 \nGPT-based models generate \nstructured test scripts from \ncode. \nLacks execution \norchestration. \n5 Multi-Agent AI for \nIntelligent Automation \nGoogle \nDeepMind \n2024 \nCooperative agents divide \ntesting tasks for parallel \nexecution. \nCoordination and system \ncomplexity issues. \n6 \nTransfer Learning \nTechniques for Software \nDefect Prediction \nP. N. \nRamesh et \nal. \n2022 \nUses transfer learning to \nimprove defect prediction \naccuracy across projects. \nHigh computational cost. \n7 \nHybrid AI-Based Model \nfor Test Case \nPrioritization \nL. Xu and T. \nZhang \n2023 \nCombines AI methods to \nprioritize test cases in \nregression testing. \nLimited scalability for \nlarge-scale systems. \n8 \nKnowledge Graph-Driven \nCode Testing for \nDependency Management \nT. Singh \nand A. Patel 2023 \nUses knowledge graphs for \ncontext-aware test \ngeneration. \nResource-intensive \nmaintenance of knowledge \ngraphs. \n9 \nSelf-Healing Automation \nFramework for Software \nTesting \nIBM \nResearch \n2024 \nDetects and fixes flaky tests \nautomatically to reduce \nmanual effort. \nRequires continuous \nmonitoring. \n10 \nMulti-Agent Systems for \nScalable Test Execution in \nCI/CD Pipelines \nV. Rao et al. 2024 \nAgents collaborate to \ndistribute and execute tests \nefficiently. \nCoordination complexity \nincreases system overhead. \n11 \nDeep Neural Models for \nAutomated Bug Detection \nand Severity Classification \nY. Li and F. \nLiu \n2022 \nDeep learning models classify \nbugs and predict severity \nautomatically. \nNeeds large labeled \ndatasets. \n12 \nMachine Learning-Based \nDynamic Test Case \nGeneration \nA. Johnson \nand K. \nKumar \n2021 \nML techniques generate test \ncases dynamically from \nsource code. \nStruggles with rapidly \nchanging codebases. \n13 \nNLP Models for \nRequirement-to-Test \nTransformation \nJ. Wang and \nM. Zhou \n2022 \nConverts requirements \ndirectly into executable test \ncases using NLP. \nLacks integration with \ndistributed test execution.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-10-25T21:44:00+05:30', 'source': '..\\data\\pdfs\\Tester Automation review paper final.pdf', 'file_path': '..\\data\\pdfs\\Tester Automation review paper final.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': 'Pramod Jaiswar', 'subject': '', 'keywords': '', 'moddate': '2025-10-25T21:44:00+05:30', 'trapped': '', 'modDate': "D:20251025214400+05'30'", 'creationDate': "D:20251025214400+05'30'", 'page': 4}, page_content='e-ISSN: 2582-5208 \nInternational Research Journal of Modernization in Engineering Technology and Science \n( Peer-Reviewed, Open Access, Fully Refereed International Journal ) \nVolume:07/Issue:08/August-2025       Impact Factor- 8.187                              www.irjmets.com   \nwww.irjmets.com                              @International Research Journal of Modernization in Engineering, Technology and Science \n [3] \n \nTable 1: Literature Survey \nIII. \nCONCLUSION \nThis literature survey emphasizes the advancements in \nAI-driven software testing automation, particularly the \nuse of Retrieval-Augmented Generation (RAG) and \nMulti-Agent Systems (MAS). The reviewed studies \nshow that AI techniques, such as machine learning, \nNLP, deep learning, and reinforcement learning, have \nsignificantly enhanced test case generation, bug \ndetection, severity classification, and regression testing \nefficiency. RAG provides context-aware understanding \nfrom requirements and code, enabling adaptive test \ngeneration, while MAS supports distributed, parallel \ntest execution, improving scalability and minimizing \nhuman intervention. These technologies together \ncontribute to faster, more reliable, and efficient \nsoftware quality assurance. \nDespite these improvements, several research gaps \nremain. Most existing approaches address isolated \ntesting tasks rather than providing complete end-to-end \nautomation. \nChallenges \nsuch \nas \nmulti-agent \ncoordination, \nhigh \ncomputational \nrequirements, \nintegration with CI/CD pipelines, and dependency on \nlarge labeled datasets still limit real-world applicability. \nFuture research should focus on developing fully \nautonomous, self-learning testing frameworks that \noptimize resource usage, simplify coordination, and \nseamlessly integrate RAG and MAS for enterprise-\nlevel \nsoftware \ntesting. \nSuch \nsystems \npromise \ncontinuous \nlearning, \nhigher \nadaptability, \nand \nsubstantial improvements in software reliability and \nrelease cycles. \n \n \nSr \nNo \nTitle \nAuthor(s) \nYear \nPaper Summary \nResearch Gap \n14 \nUsing GPT Models for \nAutomated Code Review \nand Testing \nC. Tan and \nP. Singh \n2023 \nGPT models generate test \nscripts and assist in code \nreview. \nDoes not handle multi-\nenvironment execution. \n15 Intelligent Bug Triaging \nusing Deep Learning \nH. Das and \nN. Kapoor \n2023 \nAutomatically groups bugs \nand predicts severity using \ndeep learning. \nNeeds continuous \nretraining to maintain \naccuracy. \n16 AI-Augmented Software \nQuality Assurance \nMicrosoft \nResearch \n2024 \nIntegrates AI for test \ngeneration, execution, and \nbug analysis. \nRequires integration with \nCI/CD pipelines. \n17 \nAI-Driven Continuous \nTesting in Agile \nEnvironments \nJ. Verma et \nal. \n2023 \nAI-powered continuous \ntesting for Agile projects \nimproves speed and \nadaptability. \nChallenges in multi-agent \ncoordination. \n18 \nAutomation of Test Case \nExecution using Multi-\nAgent Reinforcement \nLearning \nH. \nChoudhary \nand M. \nSinha \n2024 \nMAS with RL optimizes task \nallocation and distributed test \nexecution. \nAgent communication adds \ncomplexity. \n19 \nRetrieval-Augmented \nGeneration for Software \nDevelopment Tasks \nY. Chen and \nR. Kumar \n2024 \nApplies RAG for context-\naware test case generation \nand bug reporting. \nRequires extensive code \nand do ...
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-10-25T21:44:00+05:30', 'source': '..\\data\\pdfs\\Tester Automation review paper final.pdf', 'file_path': '..\\data\\pdfs\\Tester Automation review paper final.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': 'Pramod Jaiswar', 'subject': '', 'keywords': '', 'moddate': '2025-10-25T21:44:00+05:30', 'trapped': '', 'modDate': "D:20251025214400+05'30'", 'creationDate': "D:20251025214400+05'30'", 'page': 5}, page_content='e-ISSN: 2582-5208 \nInternational Research Journal of Modernization in Engineering Technology and Science \n( Peer-Reviewed, Open Access, Fully Refereed International Journal ) \nVolume:07/Issue:08/August-2025       Impact Factor- 8.187                              www.irjmets.com   \nwww.irjmets.com                              @International Research Journal of Modernization in Engineering, Technology and Science \n [2] \nIV. \nREFERENCES \n[1] M. Harman, P. McMinn, M. Ali, and Y. Yoo, \n“Search-based Software Testing: Past, Present and \nFuture,” Information and Software Technology, Vol. \n91, 2017, pp. 1–31. \n[2] K. Lakhotia, A. Sharma, “Automated Test Case \nGeneration Using NLP Techniques,” International \nJournal of Computer Applications, Vol. 175, Issue 10, \n2020, pp. 12-19. \n[3] S. Chen, Y. Zhang, and H. Wang, “Reinforcement \nLearning for Regression Test Selection,” Journal of \nSoftware: Evolution and Process, Vol. 33, Issue 5, \n2021. \n[4] OpenAI, “Using Large Language Models for Code \nUnderstanding and Generation,” OpenAI Technical \nReport, 2023. \n[5] Google DeepMind, “Multi-Agent Systems for Task \nAutomation,” AI Journal, Vol. 10, Issue 2, 2024, pp. \n45–57. \n[6] M. Harman and B. F. Jones, “Search-based \nSoftware Engineering: Techniques, Taxonomy, and \nApplications,” Software Testing, Verification and \nReliability, Vol. 14, Issue 2, 2004, pp. 105–156. \n[7] A. Arcuri and X. Yao, “A Practical Guide for Using \nGenetic Algorithms to Generate Test Data,” Software \nTesting, Verification and Reliability, Vol. 20, 2010, pp. \n769–796. \n[8] L. Zhang, Y. Liu, and M. Zhang, “Automated Bug \nDetection using Deep Learning,” International Journal \nof Software Engineering and Knowledge Engineering, \nVol. 28, No. 7, 2018, pp. 935–954. \n[9] K. Beck, “Test-Driven Development by Example,” \nAddison-Wesley, 2002. \n[10] N. Gupta, R. Malhotra, “AI-driven Test Case \nGeneration for Agile Development,” International \nJournal of Computer Applications, Vol. 182, Issue 10, \n2021, pp. 35–42. \n[11] S. Kim, E. Whitehead, and Y. Zhang, “Classifying \nSoftware \nChanges: \nClean \nor \nBuggy?” \nIEEE \nTransactions on Software Engineering, Vol. 34, Issue \n2, 2008, pp. 181–196. \n[12] M. Fowler, “Refactoring: Improving the Design of \nExisting Code,” Addison-Wesley, 2018. \n[13] X. Chen, J. Li, “Automated Test Orchestration \nUsing Multi-Agent Systems,” International Journal of \nSoftware Tools for Technology Transfer, Vol. 25, \n2023, pp. 101–115. \n[14] H. Nguyen, D. Nguyen, “Deep Learning \nApproaches for Software Defect Prediction,” Journal of \nSystems and Software, Vol. 160, 2020, pp. 110–124. \n[15] F. Ricci, L. Rokach, B. Shapira, “Recommender \nSystems Handbook,” Springer, 2015. \n[16] T. Mohana Priya, Dr. M. Punithavalli & Dr. R. \nRajesh Kanna, “Machine Learning Algorithm for \nDevelopment of Enhanced Support Vector Machine \nTechnique to Predict Stress,” Global Journal of \nComputer Science and Technology: C Software & Data \nEngineering, Vol. 20, Issue 2, No. 2020, pp. 12-20. \n[17] Ganesh Kumar and P. Vasanth Sena, “Novel \nArtificial Neural Networks and Logistic Approach for \nDetecting Credit Card Deceit,” International Journal of \nComputer Science and Network Security, Vol. 15, Issue \n9, Sep. 2015, pp. 222-234. \n[18] M. Harman, “The Role of Artificial Intelligence in \nSoftware Testing,” Software Quality Journal, Vol. 28, \n2020, pp. 1 ...
